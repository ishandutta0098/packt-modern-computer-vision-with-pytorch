# %% [markdown]
# # Understading Selective Search

# %%
# %cd ..
# Out:
# d:\book-implementations\packt-modern-computer-vision-with-pytorch

# %% [markdown]
# ## Preliminaries

# %%
# !pip install selectivesearch
# !pip install torch_snippets

from torch_snippets import *
import selectivesearch
from skimage.segmentation import felzenszwalb
import urllib.request

# %%
urllib.request.urlretrieve("https://www.dropbox.com/s/l98leemr7r5stnm/Hemanvi.jpeg", "Hemanvi.jpeg")
img = read("images/Hemanvi.jpeg", 1)

# %%
# Get segments
segments_fz = felzenszwalb(img, scale=100)

# %%
subplots([img, segments_fz], titles=['Original Image','Image post \nfelzenszwalb segmentation'], figsize=(10,10), nc=2)
