# %% [markdown]
# # Inspecting Grayscale Images

# %%
# !wget https://www.dropbox.com/s/l98leemr7r5stnm/Hemanvi.jpeg

# %%
# Imports

import cv2 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
# Load Image
img = cv2.imread('D:/book-implementations/packt-modern-computer-vision-with-pytorch/3-building-deep-nn-with-pytorch/images/Hemanvi.jpeg')

# %%
# Crop Image
img = img[50:250, 40:240]

# %%
# Convert image to grayscale
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Plot image
plt.imshow(img_gray, cmap='gray')

# %%
# Resize image
img_gray_small = cv2.resize(img_gray, (25,25))

# Plot
plt.imshow(img_gray_small, cmap='gray')

# %%
# Pixel Values
print(img_gray_small)
# Out:
# [[221 221 221 220 217 250 233 245 238 235 239 242 235 229 213 190 228 229
#   234 238 138 243 252 252 253]
#  [221 219 219 217 230 240 183 237 230 224 225 225 212 210 202 189 198 229
#   233 238 147 235 252 252 253]
#  [218 219 218 218 247 156 219 241 232 236 235 230 223 203 185 164 172 181
#   233 236 160 217 252 252 253]
#  [218 219 216 212 192 242 233 226 243 239 229 221 199 207 206 186 176 182
#   199 235 167 204 251 252 251]
#  [218 215 212 240 196 240 224 244 245 248 235 207 199 193 174 167 176 176
#   177 229 176 191 251 252 253]
#  [212 211 209 231 250 230 250 238 233 190 157 160 164 164 162 163 169 177
#   178 180 189 178 250 251 252]
#  [211 208 207 231 240 252 209 188 217 156 158 164 165 167 169 168 170 170
#   175 177 205 167 250 250 251]
#  [210 208 204 243 241 223 190 238 211 180 166 162 159 158 160 169 172 178
#   176 177 188 153 247 250 252]
#  [210 207 202 231 227 232 238 214 211 193 197 182 174 176 178 170 174 177
#   177 177 176 139 246 250 252]
# ...
